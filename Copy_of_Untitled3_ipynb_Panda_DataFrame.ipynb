# %% [markdown]
# <a href="https://colab.research.google.com/github/garytjones/JUpyter/blob/master/Copy_of_Untitled3_ipynb_Panda_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-analytics-bootcamp/songs.csv')
df.info()
df.head()

trump_df = pd.read_json('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-analytics-bootcamp/tweets.json')
trump_df.info()
trump_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2229 entries, 0 to 2228
# Data columns (total 8 columns):
# Song Clean      2229 non-null object
# ARTIST CLEAN    2229 non-null object
# Release Year    1652 non-null object
# COMBINED        2229 non-null object
# First?          2229 non-null int64
# Year?           2229 non-null int64
# PlayCount       2229 non-null int64
# F*G             2229 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 29 columns):
# id                           1018 non-null int64
# entities                     1018 non-null object
# is_quote_status              1018 non-null bool
# text                         1018 non-null object
# favorited                    1018 non-null bool
# source                       1018 non-null object
# truncated                    1018 non-null bool
# ...
